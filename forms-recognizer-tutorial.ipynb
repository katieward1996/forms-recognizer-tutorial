# %% [markdown]
# ## Training a Form Recognizer model and extracting form data (Python)
#
# ### Before you start
#
# Install Python. Do this either via the Microsoft Store (recommended) or via https://www.python.org/downloads/
# ***
# Install a Python interpreter, preferrably Anaconda via https://www.anaconda.com/distribution/
# ***
# Install the required modules. To do this:
# 1. Launch the Anaconda prompt
# 2. Run the command `pip install azure`
# 3. Run the command `pip install python-dotenv`
# ***
# Create your own '.env' file. This is where we will keep all of our secrets required to run this tutorial. To do this:
# 1. Go to your local directory that you are working in.
# 2. Open a Notepad file. On the first line write `KEY=`, on the second `ENDPOINT=`, the third `SAS_URL=`, fourth `FILE_PATH=`, and on the fifth line `FILE_TYPE=`.
# 3. Save the Notepad file as '.env'
# ***
# Have data to train your model. You must have either:
# * A set of at least five forms of the same type. They can be of different file types but must be the same type of document; OR
# * A single empty form with two filled-in forms. The empty form's file name needs to include the word "empty".
# ***
#
# ### Set up your Form Recognizer resource group
# Go to the Azure portal (https://portal.azure.com/) and create a new resource group to store your Form Recognizer resource and a storage container. Once you have created the resource group, create a new Form Recognizer resource. Then, create a Storage Account.
#
# Now that we have established the resources that we need, we can go ahead and find and save our secrets.
#
# #### Saving your key and endpoint values
# From within you Form Recognizer resource, select the **Quick start** tab to view your subscription data. Save the values **Key** and **Endpoint** to your .env file for the `KEY` and `ENDPOINT` values respectively.
#
# #### Saving your SAS URL
# Navigate to your Storage Account resource. Open the **Storage Explore** tab and right-click on your container. Select **Get shared access signature**. Make sure that the **Read** and **List** permissions are checked, and click **Create**. Then copy the value in the **URL** section and paste this into the `SAS_URL` value within your .env file. Save your .env.
#
# If you do not have access to the **Storage Explorer** tab, then navigate further down to the **Shared access signature** tab (under **Settings**). Make sure that the **_all_** checkboxes are selected, leave all other settings as they are. Press **Generate SAS and connection string**. Copy the **Blob service SAS URL** and save it to your .env file. You will have to alter the SAS URL so that it includes the name of your container - see the note below.
#
# **_Note_**: Make sure that your SAS URL is of the form: `https://<storage account>.blob.core.windows.net/<container name>?<SAS value>`. If you have gotten your URL via the **Shared access signature** tab, your URL will _not_ include the `<container name>` so you will need to add this in order for your URL to work correctly. You can check the name of your container by going to your Storage Account resource, and navigating to **Blob service** > **Containers** in the side bar.
#
# ***
#
# ### Finalising your .env file
# There are two variables still unpopulated in your .env file. These should be `FILE_PATH` and `FILE_TYPE`. These two values refer to the file that you would like to analyze using your trained model.
# * `FILE_PATH` is the file path of your form (for example, `C:\temp\file.pdf`). It can also be the URL of a remote file.
# * `FILE_TYPE` is the form's file type. Supported types: `application/pdf`, `image/jpeg`, `image/png`, `image/tiff`.
#
# ### Running the code
# We should now be ready to run the below code. The first block imports all the required modules that we need to run the code. The second block confirms that we have access to your .env file.

# %%
import azure, json, os, requests
import time
from requests import get, post
from dotenv import load_dotenv

# %%
load_dotenv(verbose=True)
# Out:
# True

# %% [markdown]
# ***
# #### Train a Form Recognizer model
# The following block of code calls the the **Train Custom Model** API. This will train a Form Recognizer model with the documents that are in your Azure blob container.

# %%
########### Python Form Recognizer Labeled Async Train #############

# Endpoint URL
endpoint = os.getenv("ENDPOINT") 
post_url = endpoint + r"/formrecognizer/v2.0-preview/custom/models"
source = os.getenv("SAS_URL")
prefix = ""
includeSubFolders = False
useLabelFile = False

headers = {
    # Request headers
    'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': os.getenv("KEY"),
}

body = 	{
    "source": source,
    "sourceFilter": {
        "prefix": prefix,
        "includeSubFolders": includeSubFolders
    },
    "useLabelFile": useLabelFile
}

try:
    resp = post(url = post_url, json = body, headers = headers)
    if resp.status_code != 201:
        print("POST model failed (%s):\n%s" % (resp.status_code, json.dumps(resp.json())))
        quit()
    print("POST model succeeded:\n%s" % resp.headers)
    get_url = resp.headers["location"]
except Exception as e:
    print("POST model failed:\n%s" % str(e))
    quit()
# Out:
# POST model succeeded:
# {'Content-Length': '0', 'Location': 'https://formrecognisertest-kawar.cognitiveservices.azure.com/formrecognizer/v2.0-preview/custom/models/277d882b-16e4-40d6-8faf-17dedf9ee956', 'x-envoy-upstream-service-time': '38', 'apim-request-id': '1c601a20-6cfa-4254-bc72-a9a8adab68d4', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'x-content-type-options': 'nosniff', 'Date': 'Wed, 08 Apr 2020 01:59:33 GMT'}

# %% [markdown]
# ***
# #### Get the training results
# Running the below code will return the results of the training.

# %%
n_tries = 15
n_try = 0
wait_sec = 5
max_wait_sec = 60
while n_try < n_tries:
    try:
        resp = get(url = get_url, headers = headers)
        resp_json = resp.json()
        if resp.status_code != 200:
            print("GET model failed (%s):\n%s" % (resp.status_code, json.dumps(resp_json)))
            quit()
        model_status = resp_json["modelInfo"]["status"]
        if model_status == "ready":
            print("Training succeeded:\n%s" % json.dumps(resp_json, indent=4, sort_keys=True))
            modelID = resp_json["modelInfo"]["modelId"]
            print("ModelID:\n%s" % modelID)
            break
        if model_status == "invalid":
            print("Training failed. Model is invalid:\n%s" % json.dumps(resp_json))
            quit()
        # Training still running. Wait and retry.
        time.sleep(wait_sec)
        n_try += 1
        wait_sec = min(2*wait_sec, max_wait_sec)     
    except Exception as e:
        msg = "GET model failed:\n%s" % str(e)
        print(msg)
        quit()
# Out:
# Training succeeded:
# {
#     "modelInfo": {
#         "createdDateTime": "2020-04-08T01:59:33Z",
#         "lastUpdatedDateTime": "2020-04-08T01:59:44Z",
#         "modelId": "277d882b-16e4-40d6-8faf-17dedf9ee956",
#         "status": "ready"
#     },
#     "trainResult": {
#         "errors": [],
#         "trainingDocuments": [
#             {
#                 "documentName": "EmptyPage1.png",
#                 "errors": [],
#                 "pages": 1,
#                 "status": "succeeded"
#             },
#             {
#                 "documentName": "Form1.png",
#                 "errors": [],
#                 "pages": 1,
#                 "status": "succeeded"
#             },
#             {
#                 "documentName": "Form2.png",
#                 "errors": [],
#                 "pages": 1,
#                 "status": "succeeded"
#             }
#         ]
#     }
# }
# ModelID:
# 277d882b-16e4-40d6-8faf-17dedf9ee956

# %% [markdown]
# ***
# #### Analyse your forms for key-value pairs and tables
# Now we'll use the newly trained model to analyze a document and extract key-value pairs and tables from it. We do this by calling the **Analyze Form** API.

# %%
########### Python Form Recognizer Async Analyze #############

# Endpoint URL
apim_key = os.getenv("KEY")
post_url = endpoint + "/formrecognizer/v2.0-preview/custom/models/%s/analyze" % modelID
source = os.getenv("FILE_PATH")
params = {
    "includeTextDetails": True
}

headers = {
    # Request headers
    'Content-Type': os.getenv("FILE_TYPE"),
    'Ocp-Apim-Subscription-Key': apim_key,
}
with open(source, "rb") as f:
    data_bytes = f.read()

try:
    resp = post(url = post_url, data = data_bytes, headers = headers, params = params)
    if resp.status_code != 202:
        print("POST analyze failed:\n%s" % json.dumps(resp.json()))
        quit()
    print("POST analyze succeeded:\n%s" % resp.headers)
    get_url = resp.headers["operation-location"]
except Exception as e:
    print("POST analyze failed:\n%s" % str(e))
    quit()
# Out:
# POST analyze succeeded:
# {'Content-Length': '0', 'Operation-Location': 'https://formrecognisertest-kawar.cognitiveservices.azure.com/formrecognizer/v2.0-preview/custom/models/277d882b-16e4-40d6-8faf-17dedf9ee956/analyzeresults/1d3ac21a-1448-4fc5-8081-27f7fec8955f', 'x-envoy-upstream-service-time': '179', 'apim-request-id': '00e25250-1f42-4506-b660-45bd855ba42f', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'x-content-type-options': 'nosniff', 'Date': 'Wed, 08 Apr 2020 01:59:54 GMT'}

# %% [markdown]
# ***
# #### Get the Analyze results
# This code returns the analysis results as JSON content.

# %%
n_tries = 15
n_try = 0
wait_sec = 5
max_wait_sec = 60
while n_try < n_tries:
    try:
        resp = get(url = get_url, headers = {"Ocp-Apim-Subscription-Key": apim_key})
        resp_json = resp.json()
        if resp.status_code != 200:
            print("GET analyze results failed:\n%s" % json.dumps(resp_json))
            quit()
        status = resp_json["status"]
        if status == "succeeded":
            print("Analysis succeeded:\n%s" % json.dumps(resp_json,indent=4, sort_keys=True))
            break
        if status == "failed":
            print("Analysis failed:\n%s" % json.dumps(resp_json))
            quit()
        # Analysis still running. Wait and retry.
        time.sleep(wait_sec)
        n_try += 1
        wait_sec = min(2*wait_sec, max_wait_sec)     
    except Exception as e:
        msg = "GET analyze results failed:\n%s" % str(e)
        print(msg)
        quit()
# Out:
# Analysis succeeded:
# {
#     "analyzeResult": {
#         "documentResults": [],
#         "errors": [],
#         "pageResults": [
#             {
#                 "clusterId": 0,
#                 "keyValuePairs": [
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 139,
#                                 180,
#                                 181,
#                                 180,
#                                 181,
#                                 194,
#                                 139,
#                                 194
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/13/words/0"
#                             ],
#                             "text": "Latitude:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 184,
#                                 180,
#                                 380,
#                                 180,
#                                 380,
#                                 194,
#                                 184,
#                                 194
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/14/words/0",
#                                 "#/readResults/0/lines/14/words/1"
#                             ],
#                             "text": ".....7..4.8.AS. G.Q......4."
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 139,
#                                 201,
#                                 190,
#                                 201,
#                                 190,
#                                 215,
#                                 139,
#                                 215
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/17/words/0"
#                             ],
#                             "text": "Longitude:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 192,
#                                 201,
#                                 364,
#                                 201,
#                                 364,
#                                 215,
#                                 192,
#                                 215
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/18/words/0",
#                                 "#/readResults/0/lines/18/words/1"
#                             ],
#                             "text": "...2.2.....4 4.Zu........."
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 21,
#                                 282,
#                                 129,
#                                 282,
#                                 129,
#                                 292,
#                                 21,
#                                 292
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/23/words/0"
#                             ],
#                             "text": "Location/Municipality"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 160,
#                                 286,
#                                 265,
#                                 286,
#                                 265,
#                                 300,
#                                 160,
#                                 300
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/25/words/0"
#                             ],
#                             "text": "AHAMAdaNA"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 20,
#                                 300,
#                                 61,
#                                 300,
#                                 61,
#                                 310,
#                                 20,
#                                 310
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/26/words/0"
#                             ],
#                             "text": "Country:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 181,
#                                 305,
#                                 197,
#                                 305,
#                                 197,
#                                 318,
#                                 181,
#                                 318
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/28/words/0",
#                                 "#/readResults/0/lines/28/words/1"
#                             ],
#                             "text": "S /"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 20,
#                                 323,
#                                 80,
#                                 323,
#                                 80,
#                                 334,
#                                 20,
#                                 334
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/29/words/0",
#                                 "#/readResults/0/lines/29/words/1"
#                             ],
#                             "text": "Survey date:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 472,
#                                 324,
#                                 639,
#                                 324,
#                                 639,
#                                 334,
#                                 472,
#                                 334
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/30/words/0",
#                                 "#/readResults/0/lines/30/words/1",
#                                 "#/readResults/0/lines/30/words/2",
#                                 "#/readResults/0/lines/30/words/3"
#                             ],
#                             "text": "Date survey undertaken (do/mm/yyy)"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 20,
#                                 342,
#                                 78,
#                                 342,
#                                 78,
#                                 353,
#                                 20,
#                                 353
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/31/words/0",
#                                 "#/readResults/0/lines/31/words/1",
#                                 "#/readResults/0/lines/31/words/2"
#                             ],
#                             "text": "Site ID code:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 19,
#                                 364,
#                                 127,
#                                 364,
#                                 127,
#                                 411,
#                                 19,
#                                 411
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/34/words/0",
#                                 "#/readResults/0/lines/38/words/0",
#                                 "#/readResults/0/lines/38/words/1",
#                                 "#/readResults/0/lines/38/words/2"
#                             ],
#                             "text": "name: name of photographer"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 473,
#                                 368,
#                                 558,
#                                 368,
#                                 558,
#                                 378,
#                                 473,
#                                 378
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/35/words/0",
#                                 "#/readResults/0/lines/35/words/1",
#                                 "#/readResults/0/lines/35/words/2",
#                                 "#/readResults/0/lines/35/words/3"
#                             ],
#                             "text": "Unique name of site"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 471,
#                                 402,
#                                 572,
#                                 402,
#                                 572,
#                                 411,
#                                 471,
#                                 411
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/39/words/0",
#                                 "#/readResults/0/lines/39/words/1",
#                                 "#/readResults/0/lines/39/words/2",
#                                 "#/readResults/0/lines/39/words/3",
#                                 "#/readResults/0/lines/39/words/4"
#                             ],
#                             "text": "photos taken at the site"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 335,
#                                 427,
#                                 444,
#                                 427,
#                                 444,
#                                 439,
#                                 335,
#                                 439
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/42/words/0"
#                             ],
#                             "text": "Commercial/Municipal"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 471,
#                                 429,
#                                 654,
#                                 429,
#                                 654,
#                                 439,
#                                 471,
#                                 439
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/43/words/0",
#                                 "#/readResults/0/lines/43/words/1",
#                                 "#/readResults/0/lines/43/words/2",
#                                 "#/readResults/0/lines/43/words/3",
#                                 "#/readResults/0/lines/43/words/4",
#                                 "#/readResults/0/lines/43/words/5",
#                                 "#/readResults/0/lines/43/words/6"
#                             ],
#                             "text": "Circle best option to describe the dominant"
#                         }
#                     },
#                     {
#                         "confidence": 0.5,
#                         "key": {
#                             "boundingBox": [
#                                 19,
#                                 433,
#                                 112,
#                                 433,
#                                 112,
#                                 444,
#                                 19,
#                                 444
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/44/words/0",
#                                 "#/readResults/0/lines/44/words/1",
#                                 "#/readResults/0/lines/44/words/2"
#                             ],
#                             "text": "Dominant land use"
#                         },
#                         "value": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": ""
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 369,
#                                 443,
#                                 413,
#                                 443,
#                                 413,
#                                 454,
#                                 369,
#                                 454
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/47/words/0"
#                             ],
#                             "text": "Roadway"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 471,
#                                 444,
#                                 551,
#                                 444,
#                                 551,
#                                 454,
#                                 471,
#                                 454
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/48/words/0",
#                                 "#/readResults/0/lines/48/words/1",
#                                 "#/readResults/0/lines/48/words/2",
#                                 "#/readResults/0/lines/48/words/3",
#                                 "#/readResults/0/lines/48/words/4"
#                             ],
#                             "text": "land use at the site"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 138,
#                                 474,
#                                 233,
#                                 474,
#                                 233,
#                                 487,
#                                 138,
#                                 487
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/49/words/0",
#                                 "#/readResults/0/lines/49/words/1",
#                                 "#/readResults/0/lines/49/words/2",
#                                 "#/readResults/0/lines/49/words/3"
#                             ],
#                             "text": "Time of day (00:00):"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 235,
#                                 474,
#                                 315,
#                                 474,
#                                 315,
#                                 487,
#                                 235,
#                                 487
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/50/words/0"
#                             ],
#                             "text": "../._./4.........."
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": [
#                                 137,
#                                 488,
#                                 205,
#                                 488,
#                                 205,
#                                 499,
#                                 137,
#                                 499
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/53/words/0",
#                                 "#/readResults/0/lines/53/words/1",
#                                 "#/readResults/0/lines/53/words/2"
#                             ],
#                             "text": "No. of people:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 271,
#                                 488,
#                                 296,
#                                 488,
#                                 296,
#                                 499,
#                                 271,
#                                 499
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/54/words/0"
#                             ],
#                             "text": "1.mmm"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 185,
#                                 516,
#                                 209,
#                                 516,
#                                 209,
#                                 527,
#                                 185,
#                                 527
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/57/words/0"
#                             ],
#                             "text": "Clear"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 206,
#                                 537,
#                                 222,
#                                 537,
#                                 222,
#                                 549,
#                                 206,
#                                 549
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/62/words/0"
#                             ],
#                             "text": "(1"
#                         }
#                     },
#                     {
#                         "confidence": 0.95,
#                         "key": {
#                             "boundingBox": [
#                                 236,
#                                 517,
#                                 287,
#                                 517,
#                                 287,
#                                 527,
#                                 236,
#                                 527
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/58/words/0"
#                             ],
#                             "text": "Rain/Storm"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 247,
#                                 559,
#                                 277,
#                                 559,
#                                 277,
#                                 602,
#                                 247,
#                                 602
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/74/words/0",
#                                 "#/readResults/0/lines/84/words/0"
#                             ],
#                             "text": "5 SE"
#                         }
#                     },
#                     {
#                         "confidence": 0.95,
#                         "key": {
#                             "boundingBox": [
#                                 317,
#                                 517,
#                                 361,
#                                 517,
#                                 361,
#                                 527,
#                                 317,
#                                 527
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/59/words/0"
#                             ],
#                             "text": "Overcast"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 313,
#                                 539,
#                                 322,
#                                 539,
#                                 322,
#                                 549,
#                                 313,
#                                 549
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/63/words/0"
#                             ],
#                             "text": "0:"
#                         }
#                     },
#                     {
#                         "confidence": 0.95,
#                         "key": {
#                             "boundingBox": [
#                                 324,
#                                 539,
#                                 343,
#                                 539,
#                                 343,
#                                 549,
#                                 324,
#                                 549
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/64/words/0"
#                             ],
#                             "text": "calm"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 486,
#                                 538,
#                                 492,
#                                 538,
#                                 492,
#                                 549,
#                                 486,
#                                 549
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/65/words/0"
#                             ],
#                             "text": "B:"
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": [
#                                 18,
#                                 551,
#                                 79,
#                                 551,
#                                 79,
#                                 561,
#                                 18,
#                                 561
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/67/words/0",
#                                 "#/readResults/0/lines/67/words/1"
#                             ],
#                             "text": "Wind speed:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 182,
#                                 559,
#                                 188,
#                                 559,
#                                 188,
#                                 569,
#                                 182,
#                                 569
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/72/words/0"
#                             ],
#                             "text": "3"
#                         }
#                     },
#                     {
#                         "confidence": 0.95,
#                         "key": {
#                             "boundingBox": [
#                                 323,
#                                 563,
#                                 467,
#                                 563,
#                                 467,
#                                 574,
#                                 323,
#                                 574
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/76/words/0",
#                                 "#/readResults/0/lines/76/words/1",
#                                 "#/readResults/0/lines/76/words/2",
#                                 "#/readResults/0/lines/76/words/3",
#                                 "#/readResults/0/lines/76/words/4"
#                             ],
#                             "text": "mod. breeze (10-25km/h, 6-20 kn)"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 326,
#                                 591,
#                                 338,
#                                 591,
#                                 338,
#                                 602,
#                                 326,
#                                 602
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/86/words/0"
#                             ],
#                             "text": "SW"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 18,
#                                 582,
#                                 96,
#                                 582,
#                                 96,
#                                 592,
#                                 18,
#                                 592
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/79/words/0",
#                                 "#/readResults/0/lines/79/words/1"
#                             ],
#                             "text": "Wind direction:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 189,
#                                 591,
#                                 203,
#                                 591,
#                                 203,
#                                 602,
#                                 189,
#                                 602
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/82/words/0"
#                             ],
#                             "text": "NE"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 22,
#                                 597,
#                                 63,
#                                 597,
#                                 63,
#                                 608,
#                                 22,
#                                 608
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/90/words/0"
#                             ],
#                             "text": "compass"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 19,
#                                 644,
#                                 87,
#                                 644,
#                                 87,
#                                 655,
#                                 19,
#                                 655
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/94/words/0",
#                                 "#/readResults/0/lines/94/words/1",
#                                 "#/readResults/0/lines/94/words/2"
#                             ],
#                             "text": "Access to site:"
#                         }
#                     },
#                     {
#                         "confidence": 0.45,
#                         "key": {
#                             "boundingBox": [
#                                 19,
#                                 619,
#                                 120,
#                                 619,
#                                 120,
#                                 631,
#                                 19,
#                                 631
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/92/words/0",
#                                 "#/readResults/0/lines/92/words/1",
#                                 "#/readResults/0/lines/92/words/2",
#                                 "#/readResults/0/lines/92/words/3",
#                                 "#/readResults/0/lines/92/words/4"
#                             ],
#                             "text": "Take of last clean up:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 471,
#                                 619,
#                                 511,
#                                 619,
#                                 511,
#                                 631,
#                                 471,
#                                 631
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/93/words/0",
#                                 "#/readResults/0/lines/93/words/1"
#                             ],
#                             "text": "If known"
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 390,
#                                 642,
#                                 466,
#                                 642,
#                                 466,
#                                 658,
#                                 390,
#                                 658
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/98/words/0",
#                                 "#/readResults/0/lines/98/words/1"
#                             ],
#                             "text": "Other (specify):"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 480,
#                                 649,
#                                 544,
#                                 649,
#                                 544,
#                                 668,
#                                 480,
#                                 668
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/99/words/0"
#                             ],
#                             "text": "through"
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": [
#                                 18,
#                                 670,
#                                 187,
#                                 670,
#                                 187,
#                                 683,
#                                 18,
#                                 683
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/101/words/0",
#                                 "#/readResults/0/lines/101/words/1",
#                                 "#/readResults/0/lines/101/words/2",
#                                 "#/readResults/0/lines/101/words/3",
#                                 "#/readResults/0/lines/101/words/4",
#                                 "#/readResults/0/lines/101/words/5"
#                             ],
#                             "text": "Trash cans or rubbish bins present?"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 256,
#                                 674,
#                                 270,
#                                 674,
#                                 270,
#                                 683,
#                                 256,
#                                 683
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/102/words/0"
#                             ],
#                             "text": "Yes"
#                         }
#                     },
#                     {
#                         "confidence": 0.5,
#                         "key": {
#                             "boundingBox": [
#                                 18,
#                                 801,
#                                 188,
#                                 801,
#                                 188,
#                                 812,
#                                 18,
#                                 812
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/118/words/0",
#                                 "#/readResults/0/lines/118/words/1",
#                                 "#/readResults/0/lines/118/words/2",
#                                 "#/readResults/0/lines/118/words/3",
#                                 "#/readResults/0/lines/118/words/4",
#                                 "#/readResults/0/lines/118/words/5"
#                             ],
#                             "text": "Evidence of recent activities at site:"
#                         },
#                         "value": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": ""
#                         }
#                     },
#                     {
#                         "confidence": 0.5,
#                         "key": {
#                             "boundingBox": [
#                                 237,
#                                 822,
#                                 306,
#                                 822,
#                                 306,
#                                 833,
#                                 237,
#                                 833
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/120/words/0",
#                                 "#/readResults/0/lines/120/words/1",
#                                 "#/readResults/0/lines/120/words/2"
#                             ],
#                             "text": "Storm or flood"
#                         },
#                         "value": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": ""
#                         }
#                     },
#                     {
#                         "confidence": 0.7,
#                         "key": {
#                             "boundingBox": [
#                                 18,
#                                 845,
#                                 77,
#                                 845,
#                                 77,
#                                 859,
#                                 18,
#                                 859
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/124/words/0"
#                             ],
#                             "text": "Comments:"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 83,
#                                 845,
#                                 104,
#                                 845,
#                                 104,
#                                 859,
#                                 83,
#                                 859
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/125/words/0"
#                             ],
#                             "text": "No"
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": "__Tokens__1"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 499,
#                                 4,
#                                 513,
#                                 4,
#                                 513,
#                                 26,
#                                 499,
#                                 26
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/0/words/0"
#                             ],
#                             "text": "v"
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": "__Tokens__2"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 568,
#                                 4,
#                                 655,
#                                 4,
#                                 655,
#                                 26,
#                                 568,
#                                 26
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/1/words/0"
#                             ],
#                             "text": "finished"
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": "__Tokens__3"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 248,
#                                 30,
#                                 437,
#                                 30,
#                                 437,
#                                 45,
#                                 248,
#                                 45
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/2/words/0",
#                                 "#/readResults/0/lines/2/words/1",
#                                 "#/readResults/0/lines/2/words/2"
#                             ],
#                             "text": "INLAND SITE INFORMATION"
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": "__Tokens__4"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 22,
#                                 67,
#                                 117,
#                                 67,
#                                 117,
#                                 77,
#                                 22,
#                                 77
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/3/words/0",
#                                 "#/readResults/0/lines/3/words/1"
#                             ],
#                             "text": "SURVEYOR DETAILS"
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": "__Tokens__5"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 162,
#                                 115,
#                                 208,
#                                 115,
#                                 208,
#                                 130,
#                                 162,
#                                 130
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/8/words/0"
#                             ],
#                             "text": "spiel"
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": "__Tokens__6"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 22,
#                                 223,
#                                 87,
#                                 223,
#                                 87,
#                                 234,
#                                 22,
#                                 234
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/20/words/0",
#                                 "#/readResults/0/lines/20/words/1"
#                             ],
#                             "text": "GPS Accuracy"
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": "__Tokens__7"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 21,
#                                 257,
#                                 83,
#                                 257,
#                                 83,
#                                 268,
#                                 21,
#                                 268
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/22/words/0",
#                                 "#/readResults/0/lines/22/words/1"
#                             ],
#                             "text": "SITE DETAILS"
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": "__Tokens__8"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 474,
#                                 281,
#                                 564,
#                                 281,
#                                 564,
#                                 292,
#                                 474,
#                                 292
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/24/words/0",
#                                 "#/readResults/0/lines/24/words/1",
#                                 "#/readResults/0/lines/24/words/2",
#                                 "#/readResults/0/lines/24/words/3"
#                             ],
#                             "text": "Town location of site"
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": "__Tokens__9"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 474,
#                                 303,
#                                 618,
#                                 303,
#                                 618,
#                                 313,
#                                 474,
#                                 313
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/27/words/0",
#                                 "#/readResults/0/lines/27/words/1",
#                                 "#/readResults/0/lines/27/words/2",
#                                 "#/readResults/0/lines/27/words/3",
#                                 "#/readResults/0/lines/27/words/4",
#                                 "#/readResults/0/lines/27/words/5"
#                             ],
#                             "text": "Country in which site was sampled"
#                         }
#                     },
#                     {
#                         "confidence": 1.0,
#                         "key": {
#                             "boundingBox": null,
#                             "elements": null,
#                             "text": "__Tokens__10"
#                         },
#                         "value": {
#                             "boundingBox": [
#                                 471,
#                                 345,
#                                 608,
#                                 345,
#                                 608,
#                                 356,
#                                 471,
#                                 356
#                             ],
#                             "elements": [
#                                 "#/readResults/0/lines/32/words/0",
#                                 "#/readResults/0/lines/32/words/1",
#                                 "#/readResults/0/lines/32/words/2",
# ...
#                             },
#                             {
#                                 "boundingBox": [
#                                     154,
#                                     801,
#                                     164,
#                                     801,
#                                     164,
#                                     812,
#                                     154,
#                                     812
#                                 ],
#                                 "text": "at"
#                             },
#                             {
#                                 "boundingBox": [
#                                     166,
#                                     801,
#                                     188,
#                                     801,
#                                     188,
#                                     812,
#                                     166,
#                                     812
#                                 ],
#                                 "text": "site:"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             17,
#                             814,
#                             109,
#                             814,
#                             109,
#                             826,
#                             17,
#                             826
#                         ],
#                         "text": "(circle one or more",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     17,
#                                     814,
#                                     47,
#                                     814,
#                                     47,
#                                     826,
#                                     17,
#                                     826
#                                 ],
#                                 "text": "(circle"
#                             },
#                             {
#                                 "boundingBox": [
#                                     49,
#                                     814,
#                                     67,
#                                     814,
#                                     67,
#                                     826,
#                                     49,
#                                     826
#                                 ],
#                                 "text": "one"
#                             },
#                             {
#                                 "boundingBox": [
#                                     70,
#                                     814,
#                                     80,
#                                     814,
#                                     80,
#                                     826,
#                                     70,
#                                     826
#                                 ],
#                                 "text": "or"
#                             },
#                             {
#                                 "boundingBox": [
#                                     82,
#                                     814,
#                                     109,
#                                     814,
#                                     109,
#                                     826,
#                                     82,
#                                     826
#                                 ],
#                                 "text": "more"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             237,
#                             822,
#                             306,
#                             822,
#                             306,
#                             833,
#                             237,
#                             833
#                         ],
#                         "text": "Storm or flood",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     237,
#                                     822,
#                                     263,
#                                     822,
#                                     263,
#                                     833,
#                                     237,
#                                     833
#                                 ],
#                                 "text": "Storm"
#                             },
#                             {
#                                 "boundingBox": [
#                                     268,
#                                     822,
#                                     279,
#                                     822,
#                                     279,
#                                     833,
#                                     268,
#                                     833
#                                 ],
#                                 "text": "or"
#                             },
#                             {
#                                 "boundingBox": [
#                                     281,
#                                     822,
#                                     306,
#                                     822,
#                                     306,
#                                     833,
#                                     281,
#                                     833
#                                 ],
#                                 "text": "flood"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             337,
#                             822,
#                             390,
#                             822,
#                             390,
#                             833,
#                             337,
#                             833
#                         ],
#                         "text": "High winds",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     337,
#                                     822,
#                                     359,
#                                     822,
#                                     359,
#                                     833,
#                                     337,
#                                     833
#                                 ],
#                                 "text": "High"
#                             },
#                             {
#                                 "boundingBox": [
#                                     361,
#                                     822,
#                                     390,
#                                     822,
#                                     390,
#                                     833,
#                                     361,
#                                     833
#                                 ],
#                                 "text": "winds"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             425,
#                             822,
#                             485,
#                             822,
#                             485,
#                             833,
#                             425,
#                             833
#                         ],
#                         "text": "Public event",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     425,
#                                     822,
#                                     455,
#                                     822,
#                                     455,
#                                     833,
#                                     425,
#                                     833
#                                 ],
#                                 "text": "Public"
#                             },
#                             {
#                                 "boundingBox": [
#                                     457,
#                                     822,
#                                     485,
#                                     822,
#                                     485,
#                                     833,
#                                     457,
#                                     833
#                                 ],
#                                 "text": "event"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             541,
#                             822,
#                             582,
#                             822,
#                             582,
#                             833,
#                             541,
#                             833
#                         ],
#                         "text": "Mowing",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     541,
#                                     822,
#                                     582,
#                                     822,
#                                     582,
#                                     833,
#                                     541,
#                                     833
#                                 ],
#                                 "text": "Mowing"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             18,
#                             845,
#                             77,
#                             845,
#                             77,
#                             859,
#                             18,
#                             859
#                         ],
#                         "text": "Comments:",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     18,
#                                     845,
#                                     77,
#                                     845,
#                                     77,
#                                     859,
#                                     18,
#                                     859
#                                 ],
#                                 "text": "Comments:"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             83,
#                             845,
#                             104,
#                             845,
#                             104,
#                             859,
#                             83,
#                             859
#                         ],
#                         "text": "No",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     83,
#                                     845,
#                                     104,
#                                     845,
#                                     104,
#                                     859,
#                                     83,
#                                     859
#                                 ],
#                                 "text": "No"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             121,
#                             845,
#                             165,
#                             845,
#                             165,
#                             859,
#                             121,
#                             859
#                         ],
#                         "text": "MeA7",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     121,
#                                     845,
#                                     165,
#                                     845,
#                                     165,
#                                     859,
#                                     121,
#                                     859
#                                 ],
#                                 "text": "MeA7"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             29,
#                             867,
#                             61,
#                             867,
#                             61,
#                             884,
#                             29,
#                             884
#                         ],
#                         "text": "this",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     29,
#                                     867,
#                                     61,
#                                     867,
#                                     61,
#                                     884,
#                                     29,
#                                     884
#                                 ],
#                                 "text": "this"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             74,
#                             867,
#                             116,
#                             867,
#                             116,
#                             884,
#                             74,
#                             884
#                         ],
#                         "text": "side",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     74,
#                                     867,
#                                     116,
#                                     867,
#                                     116,
#                                     884,
#                                     74,
#                                     884
#                                 ],
#                                 "text": "side"
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             134,
#                             867,
#                             156,
#                             867,
#                             156,
#                             884,
#                             134,
#                             884
#                         ],
#                         "text": "ag",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     134,
#                                     867,
#                                     156,
#                                     867,
#                                     156,
#                                     884,
#                                     134,
#                                     884
#                                 ],
#                                 "text": "ag"
#                             }
#                         ]
#                     }
#                 ],
#                 "page": 1,
#                 "unit": "pixel",
#                 "width": 694
#             }
#         ],
#         "version": "2.0.0"
#     },
#     "createdDateTime": "2020-04-08T01:59:55Z",
#     "lastUpdatedDateTime": "2020-04-08T02:00:01Z",
#     "status": "succeeded"
# }
